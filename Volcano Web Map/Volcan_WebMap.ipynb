# %%
import folium as fo
import pandas as pn

# %%
df = pn.read_excel("volcan.xlsx")
df
# Out:
#         Number     Volcano Name        Country         Region  Latitude  \
# 0     0803-001              Abu          Japan   Honshu-Japan    34.500
# 1     1505-096       Acamarachi          Chile        Chile-N   -23.300
# 2     1402-08=       Acatenango      Guatemala      Guatemala    14.501
# 3     0103-004  Acigol-Nevsehir         Turkey         Turkey    38.570
# 4     1201-04-            Adams  United States  US-Washington    46.206
# ...        ...              ...            ...            ...       ...
# 1565  1000-12=      Zhupanovsky         Russia      Kamchatka    53.590
# 1566  1000-242           Zimina         Russia      Kamchatka    55.862
# 1567  0201-02=    Zubair, Jebel          Yemen        Red Sea    15.050
# 1568  0201-021            Zukur          Yemen        Red Sea    14.020
# 1569  1210-02-     Zuni-Bandera  United States  US-New Mexico    34.800
#
#       Longitude    Elev              Type            Status
# 0       131.600   571.0    Shield volcano          Holocene
# 1       -67.620  6046.0     Stratovolcano          Holocene
# 2       -90.876  3976.0     Stratovolcano        Historical
# 3        34.520  1689.0              Maar          Holocene
# 4      -121.490  3742.0     Stratovolcano  Tephrochronology
# ...         ...     ...               ...               ...
# 1565    159.147  2958.0  Compound volcano        Historical
# 1566    160.603  3081.0     Stratovolcano          Holocene
# 1567     42.180   191.0    Shield volcano        Historical
# 1568     42.750   624.0    Shield volcano          Holocene
# 1569   -108.000  2550.0    Volcanic field      Anthropology
#
# [1570 rows x 9 columns]

# %%
lat = list(df["Latitude"])
lon = list(df["Longitude"])
elev = list(df["Elev"])

# %%
map = fo.Map(location=[40, -100],zoom_start=6,tiles="Mapbox Bright")

# %%
fgv = fo.FeatureGroup("Volcanoes")

# %%
def color_producer(elevation):
    if elevation < 1000:
        return 'green'
    elif 1000 <= elevation < 3000:
        return 'orange'
    else:
        return 'red'

# %%
for lt, ln, el in zip(lat, lon, elev):
    fgv.add_child(fo.CircleMarker(location=[lt, ln], radius = 6, popup=str(el)+" m",
    fill_color=color_producer(el), fill=True,  color = 'grey', fill_opacity=0.7))

fgp = fo.FeatureGroup(name="Population")
fgp.add_child(fo.GeoJson(data=open('world.json', 'r', encoding='utf-8-sig').read(),
style_function=lambda x: {'fillColor':'green' if x['properties']['POP2005'] < 10000000
else 'orange' if 10000000 <= x['properties']['POP2005'] < 20000000 else 'red'}))

map.add_child(fgv)
map.add_child(fgp)
map.add_child(fo.LayerControl())

map.save("Map1.html")
